# %%
import numpy as np
import matplotlib.pyplot as plt
g=9.8

# %%
LEO=np.linspace(300,2000,100)

# %%
v_fin=(9.8*(6400e3)**2/(6400+LEO)/1e3)**0.5
delta_v=v_fin#+9.8*3*60

# %%
plt.plot(LEO,v_fin)
plt.xlabel("ORBIT (km)")
plt.ylabel("DELTA_V (m/s)")
plt.title("DELTA V for 3 min flight time")
# Out:
# Text(0.5, 1.0, 'DELTA V for 3 min flight time')

# %%
9.8*3*60
# Out:
# 1764.0000000000002

# %%
T_W=np.linspace(2,5,100)
acc=(T_W-1)*9.8
time=7400/acc
g_loss=time*9.8

# %%
plt.plot(T_W,g_loss)
plt.xlabel("T/W (m/s^2)")
plt.ylabel("DELTA_V (m/s)")
plt.title("DELTA V loss due to gravity for orbital velocity of 7400 m/s")
# Out:
# Text(0.5, 1.0, 'DELTA V loss due to gravity for orbital velocity of 7400 m/s')

# %%
a=np.array(0)

# %%
a=np.append(a,2)

# %%
a
# Out:
# array([0, 2])

# %%
37*9.8
# Out:
# 362.6

# %%
160*9.8
# Out:
# 1568.0

# %%
fine=np.genfromtxt("fine mesh")
coarse=np.genfromtxt("coarse mesh liquid fraction")

# %%
plt.scatter(fine.T[0],fine.T[1],1)
plt.scatter(coarse.T[0],coarse.T[1],1)
plt.legend(['Fine mesh','Coarse Mesh'])
plt.xlabel('Position')
plt.ylabel('Liquid Fraction')
# Out:
# Text(0, 0.5, 'Liquid Fraction')

# %%
fine.T
# Out:
# array([[ 0.00000e+00,  2.50000e-04,  5.00000e-04, ...,  1.26000e-01,
#          1.25750e-01,  1.25500e-01],
#        [ 0.00000e+00, -3.81352e-17,  2.33412e-16, ...,  6.84739e-02,
#          6.81608e-02,  6.78468e-02]])

# %%
plt.scatter?
# Out:
# Signature:
# plt.scatter(
#     x: 'float | ArrayLike',
#     y: 'float | ArrayLike',
#     s: 'float | ArrayLike | None' = None,
#     c: 'ArrayLike | Sequence[ColorType] | ColorType | None' = None,
#     marker: 'MarkerType | None' = None,
#     cmap: 'str | Colormap | None' = None,
#     norm: 'str | Normalize | None' = None,
#     vmin: 'float | None' = None,
#     vmax: 'float | None' = None,
#     alpha: 'float | None' = None,
#     linewidths: 'float | Sequence[float] | None' = None,
#     *,
#     edgecolors: "Literal['face', 'none'] | ColorType | Sequence[ColorType] | None" = None,
#     plotnonfinite: 'bool' = False,
#     data=None,
#     **kwargs,
# ) -> 'PathCollection'
# Docstring:
# A scatter plot of *y* vs. *x* with varying marker size and/or color.
#
# Parameters
# ----------
# x, y : float or array-like, shape (n, )
#     The data positions.
#
# s : float or array-like, shape (n, ), optional
#     The marker size in points**2 (typographic points are 1/72 in.).
# ...

# %%
a=[0,1,2,3,4]

# %%
a[4:]
# Out:
# [4]

# %%
a=1

# %%
print("a=",a+1,"\t\t",end="")
print("Fuvk")
# Out:
# a= 2 		Fuvk

# %%
round(np.pi,0)
# Out:
# 3.0

# %%
a=np.array([0,1,2,3])

# %%
a=np.append(a,4)

# %%
# Out:
# array([0, 1, 2, 3, 4, 4])

# %%
# Out:
# 0

# %%
(61-57)/57*100
# Out:
# 7.017543859649122

# %%
3476+5915+1200
# Out:
# 10591

# %%
10590-1200
# Out:
# 9390

# %%
311*9.8*np.log((611184+50000)/(138529+41342+50000))
# Out:
# 3220.043019358806

# %%
I=311
g=9.8
b=0.25446898
e=0.08746722
-I*g*np.log(b+(1-b)*e)
# Out:
# 3475.831379360046

# %%
472655*e-41342
# Out:
# -0.18113090000406373

# %%
3985+5915+1200
# Out:
# 11100

# %%
13455+431313-444768
# Out:
# 0

# %%
rocket_name="falcon"
str="input files/"+rocket_name+".json"

# %%
str
# Out:
# 'input files/falcon.json'
